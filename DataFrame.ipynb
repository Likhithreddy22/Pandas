# %%
import pandas as pd

# %%
data_dict = {
    'name':['Alice','Bob','Diana','Charlie'],
    'age':[25,40,35,28],
    'city':['NewYork','London','Tokyo','Paris'],
    'salary':[50000,70000,60000,55000]}

# %%
df_data_dict = pd.DataFrame(data_dict)

# %%
df_data_dict
# Out:
#       name  age     city  salary
# 0    Alice   25  NewYork   50000
# 1      Bob   40   London   70000
# 2    Diana   35    Tokyo   60000
# 3  Charlie   28    Paris   55000

# %%
df_data_dict.shape
# Out:
# (4, 4)

# %%
df_data_dict.columns
# Out:
# Index(['name', 'age', 'city', 'salary'], dtype='str')

# %%
series_dict = {
    'math':pd.Series([85,90,78],index =['alice','bob','charlie']),
    'sciecne':pd.Series([88,92,84],index = ['alice','bob','charlie']),
    'social':pd.Series([90,86,88],index = ['alice','bob','charlie'])}

# %%
df_series_dict = pd.DataFrame(series_dict)

# %%
df_series_dict
# Out:
#          math  sciecne  social
# alice      85       88      90
# bob        90       92      86
# charlie    78       84      88

# %%
data_list = [
    ['alice',27,'New York',70000],
    ['bob',28,'London',60000],
    ['charlie',29,'Tokyo',80000]]

# %%
df_data_list = pd.DataFrame(data_list,columns=['name','age','city','salary'])

# %%
df_data_list
# Out:
#       name  age      city  salary
# 0    alice   27  New York   70000
# 1      bob   28    London   60000
# 2  charlie   29     Tokyo   80000

# %%
list_dicts = [
    {'name':'Alcie','Age':29,'city':'New York'},
    {'name':'Bob','Age':32,'city':'Paris'},
    {'name':'Charlie','Age':28,'city':'Tokyo'}]

# %%
df_list_dicts = pd.DataFrame(list_dicts)

# %%
df_list_dicts
# Out:
#       name  Age      city
# 0    Alcie   29  New York
# 1      Bob   32     Paris
# 2  Charlie   28     Tokyo

# %%
import numpy as np
arr = np.array([
    [1,'Alice',25],
    [2,'Bob',28],
    [3,'Charlie',29]])

# %%
df_arr = pd.DataFrame(arr,columns=['id','name','age'])

# %%
df_arr
# Out:
#   id     name age
# 0  1    Alice  25
# 1  2      Bob  28
# 2  3  Charlie  29

# %%
df_arr.dtypes
# Out:
# id      str
# name    str
# age     str
# dtype: object

# %%
np_mixed = {
    'A':np.random.rand(5),
    'B':np.arange(5),
    'C':list('abcde')}

# %%
df_np_mixed = pd.DataFrame(np_mixed)

# %%
df_np_mixed
# Out:
#           A  B  C
# 0  0.766690  0  a
# 1  0.813502  1  b
# 2  0.684087  2  c
# 3  0.393548  3  d
# 4  0.885035  4  e
