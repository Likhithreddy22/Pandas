# %%
import pandas as pd

# %%
df = pd.read_csv('student_marks.csv')

# %%
df
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh   49.0     55.0       48.0              80.0
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# ...

# %%
df_drop1 = df.drop('Computer_Science',axis=1)

# %%
df_drop1
# Out:
#      Student_Name  Maths  Physics  Chemistry
# 0     Arjun Singh   49.0     55.0       48.0
# 1       Arjun Das   94.0     98.0       45.0
# 2    Vivaan Singh   95.0     40.0        NaN
# 3    Vivaan Patel   85.0      NaN       47.0
# 4       Sai Gupta    NaN      NaN        NaN
# 5     Aarav Mehta   87.0      NaN       78.0
# 6    Suresh Gupta   70.0     92.0        NaN
# 7    Aditya Patel   51.0     40.0        NaN
# 8     Rahul Reddy    NaN     51.0        NaN
# 9     Rahul Singh    NaN     56.0       90.0
# 10    Rahul Kumar    NaN      NaN       46.0
# 11        Sai Das   52.0      NaN        NaN
# 12  Karthik Reddy   36.0      NaN       83.0
# 13  Aditya Sharma   72.0     87.0        NaN
# 14   Nikhil Patel    NaN      NaN        NaN
# 15    Aarav Reddy    NaN      NaN       89.0
# 16    Rahul Singh   73.0     37.0        NaN
# 17  Karthik Kumar    NaN     68.0       63.0
# 18    Rahul Mehta   75.0     72.0        NaN
# 19    Vivaan Iyer   95.0      NaN        NaN
# ...

# %%
 df_drop2 = df.drop(['Maths','Physics'],axis=1)

# %%
df_drop2
# Out:
#      Student_Name  Chemistry  Computer_Science
# 0     Arjun Singh       48.0              80.0
# 1       Arjun Das       45.0              68.0
# 2    Vivaan Singh        NaN              49.0
# 3    Vivaan Patel       47.0               NaN
# 4       Sai Gupta        NaN              92.0
# 5     Aarav Mehta       78.0              66.0
# 6    Suresh Gupta        NaN               NaN
# 7    Aditya Patel        NaN              47.0
# 8     Rahul Reddy        NaN              83.0
# 9     Rahul Singh       90.0              55.0
# 10    Rahul Kumar       46.0               NaN
# 11        Sai Das        NaN               NaN
# 12  Karthik Reddy       83.0               NaN
# 13  Aditya Sharma        NaN               NaN
# 14   Nikhil Patel        NaN              76.0
# 15    Aarav Reddy       89.0              63.0
# 16    Rahul Singh        NaN              92.0
# 17  Karthik Kumar       63.0              58.0
# 18    Rahul Mehta        NaN              38.0
# ...

# %%
df_drop3 = df.drop(['Chemistry'], axis=1 , inplace=True)

# %%
df
# Out:
#      Student_Name  Maths  Physics  Computer_Science
# 0     Arjun Singh   49.0     55.0              80.0
# 1       Arjun Das   94.0     98.0              68.0
# 2    Vivaan Singh   95.0     40.0              49.0
# 3    Vivaan Patel   85.0      NaN               NaN
# 4       Sai Gupta    NaN      NaN              92.0
# 5     Aarav Mehta   87.0      NaN              66.0
# 6    Suresh Gupta   70.0     92.0               NaN
# 7    Aditya Patel   51.0     40.0              47.0
# 8     Rahul Reddy    NaN     51.0              83.0
# 9     Rahul Singh    NaN     56.0              55.0
# 10    Rahul Kumar    NaN      NaN               NaN
# 11        Sai Das   52.0      NaN               NaN
# 12  Karthik Reddy   36.0      NaN               NaN
# 13  Aditya Sharma   72.0     87.0               NaN
# 14   Nikhil Patel    NaN      NaN              76.0
# 15    Aarav Reddy    NaN      NaN              63.0
# 16    Rahul Singh   73.0     37.0              92.0
# ...
