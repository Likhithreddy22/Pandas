# %%
import pandas as pd

# %%
df = pd.read_csv('student_marks.csv')

# %%
df
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh   49.0     55.0       48.0              80.0
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# ...

# %%
df.isna()
# Out:
#     Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0          False  False    False      False             False
# 1          False  False    False      False             False
# 2          False  False    False       True             False
# 3          False  False     True      False              True
# 4          False   True     True       True             False
# 5          False  False     True      False             False
# 6          False  False    False       True              True
# 7          False  False    False       True             False
# 8          False   True    False       True             False
# 9          False   True    False      False             False
# 10         False   True     True      False              True
# 11         False  False     True       True              True
# 12         False  False     True      False              True
# 13         False  False    False       True              True
# ...

# %%
df.isna().sum()
# Out:
# Student_Name         0
# Maths               22
# Physics             25
# Chemistry           30
# Computer_Science    18
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(95)

# %%
df.dropna()
# Out:
#     Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0    Arjun Singh   49.0     55.0       48.0              80.0
# 1      Arjun Das   94.0     98.0       45.0              68.0
# 26  Aditya Mehta   59.0     85.0       39.0              76.0
# 49   Arjun Singh   49.0     55.0       48.0              80.0

# %%
df.dropna(axis=0)
# Out:
#     Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0    Arjun Singh   49.0     55.0       48.0              80.0
# 1      Arjun Das   94.0     98.0       45.0              68.0
# 26  Aditya Mehta   59.0     85.0       39.0              76.0
# 49   Arjun Singh   49.0     55.0       48.0              80.0

# %%
df.fillna('Fill')
# Out:
#      Student_Name Maths Physics Chemistry Computer_Science
# 0     Arjun Singh  49.0    55.0      48.0             80.0
# 1       Arjun Das  94.0    98.0      45.0             68.0
# 2    Vivaan Singh  95.0    40.0      Fill             49.0
# 3    Vivaan Patel  85.0    Fill      47.0             Fill
# 4       Sai Gupta  Fill    Fill      Fill             92.0
# 5     Aarav Mehta  87.0    Fill      78.0             66.0
# 6    Suresh Gupta  70.0    92.0      Fill             Fill
# 7    Aditya Patel  51.0    40.0      Fill             47.0
# 8     Rahul Reddy  Fill    51.0      Fill             83.0
# 9     Rahul Singh  Fill    56.0      90.0             55.0
# 10    Rahul Kumar  Fill    Fill      46.0             Fill
# 11        Sai Das  52.0    Fill      Fill             Fill
# 12  Karthik Reddy  36.0    Fill      83.0             Fill
# 13  Aditya Sharma  72.0    87.0      Fill             Fill
# 14   Nikhil Patel  Fill    Fill      Fill             76.0
# ...

# %%
df.fillna(45)
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh   49.0     55.0       48.0              80.0
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0       45.0              49.0
# 3    Vivaan Patel   85.0     45.0       47.0              45.0
# 4       Sai Gupta   45.0     45.0       45.0              92.0
# 5     Aarav Mehta   87.0     45.0       78.0              66.0
# 6    Suresh Gupta   70.0     92.0       45.0              45.0
# 7    Aditya Patel   51.0     40.0       45.0              47.0
# 8     Rahul Reddy   45.0     51.0       45.0              83.0
# 9     Rahul Singh   45.0     56.0       90.0              55.0
# 10    Rahul Kumar   45.0     45.0       46.0              45.0
# 11        Sai Das   52.0     45.0       45.0              45.0
# 12  Karthik Reddy   36.0     45.0       83.0              45.0
# 13  Aditya Sharma   72.0     87.0       45.0              45.0
# ...

# %%
df.duplicated(keep=False)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# dtype: bool

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# dtype: bool

# %%
df.duplicated(keep = False)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# dtype: bool

# %%
df.duplicated(keep = 'last')
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh   49.0     55.0       48.0              80.0
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# ...

# %%
df.drop_duplicates(keep = 'last')
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# 14   Nikhil Patel    NaN      NaN        NaN              76.0
# ...

# %%
df.drop_duplicates(subset=['Student_Name','Maths'])
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh   49.0     55.0       48.0              80.0
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# ...
