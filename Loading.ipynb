# %%
import pandas as pd

# %%
df_csv = pd.read_csv('student_marks.csv')

# %%
df_csv
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh   49.0     55.0       48.0              80.0
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# ...

# %%
with open('sample_data.csv','w') as f:
    f.write('''ID;Name;Age
    1;Alice;24
    2;bob;30''')

# %%
df_sample_csv = pd.read_csv('sample_data.csv', delimiter =';')

# %%
df_sample_csv
# Out:
#    ID   Name  Age
# 0   1  Alice   24
# 1   2    bob   30

# %%
df1 = pd.read_csv('student_marks.csv',
                 nrows = 3,
                 # usecols = ['Student_Name','Physics'],
                 skiprows = 1,
                 na_values = [''])

# %%
df1
# Out:
#     Arjun Singh  49    55    48    80
# 0     Arjun Das  94  98.0  45.0  68.0
# 1  Vivaan Singh  95  40.0   NaN  49.0
# 2  Vivaan Patel  85   NaN  47.0   NaN

# %%
df_excel = pd.DataFrame({
    'Product':['Laptop','Mouse','KeyBoard','Monitor'],
    'Price':[999.99,29.99,59.99,299.99],
    'Quantity':[10,50,30,15],
    'Category':['Electronics','Accessories','Accessories','Electronics']
})

# %%
df_excel.to_excel('sample_data.xlsx', index = False,sheet_name = 'Products')

# %%
df_from = pd.read_excel('sample_data.xlsx')

# %%
df_from
# Out:
#     Product   Price  Quantity     Category
# 0    Laptop  999.99        10  Electronics
# 1     Mouse   29.99        50  Accessories
# 2  KeyBoard   59.99        30  Accessories
# 3   Monitor  299.99        15  Electronics

# %%
df_sheet = pd.read_excel('student_marks.xlsx')

# %%
df_sheet
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh    NaN     55.0        NaN              80.0
# 1       Arjun Das   94.0      NaN        NaN               NaN
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# ...

# %%
with pd.ExcelWriter('sample.xlsx') as writer:
    df_excel.to_excel(writer,sheet_name = 'Products',index = False)

    df_sales = pd.DataFrame({
    'Month':['Jan','Feb','Mar'],
    'Sales':[15000,22000,18000],
    'Expenses':[8000,12000,9000]
    })
    df_sales.to_excel(writer,sheet_name='Sales',index = False)

# %%
xls = pd.ExcelFile('sample.xlsx')

# %%
print(xls)

# %%
xls.sheet_names
# Out:
# ['Products', 'Sales']

# %%
df_products = pd.read_excel(xls,sheet_name='Products')

# %%
df_products
# Out:
#     Product   Price  Quantity     Category
# 0    Laptop  999.99        10  Electronics
# 1     Mouse   29.99        50  Accessories
# 2  KeyBoard   59.99        30  Accessories
# 3   Monitor  299.99        15  Electronics

# %%
df_sales = pd.read_excel(xls,sheet_name = 'Sales')

# %%
df_sales
# Out:
#   Month  Sales  Expenses
# 0   Jan  15000      8000
# 1   Feb  22000     12000
# 2   Mar  18000      9000

# %%
df_selected = pd.read_excel('sample.xlsx',usecols=['Product','Price'])

# %%
df_selected
# Out:
#     Product   Price
# 0    Laptop  999.99
# 1     Mouse   29.99
# 2  KeyBoard   59.99
# 3   Monitor  299.99

# %%
df_limited = pd.read_excel('sample.xlsx',nrows=2)

# %%
df_limited
# Out:
#   Product   Price  Quantity     Category
# 0  Laptop  999.99        10  Electronics
# 1   Mouse   29.99        50  Accessories
