# %%
import pandas as pd

# %%
df = pd.read_csv('student_marks.csv')

# %%
df['Student_Name'] = df['Student_Name'].str.upper()

# %%
df
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     ARJUN SINGH   49.0     55.0       48.0              80.0
# 1       ARJUN DAS   94.0     98.0       45.0              68.0
# 2    VIVAAN SINGH   95.0     40.0        NaN              49.0
# 3    VIVAAN PATEL   85.0      NaN       47.0               NaN
# 4       SAI GUPTA    NaN      NaN        NaN              92.0
# 5     AARAV MEHTA   87.0      NaN       78.0              66.0
# 6    SURESH GUPTA   70.0     92.0        NaN               NaN
# 7    ADITYA PATEL   51.0     40.0        NaN              47.0
# 8     RAHUL REDDY    NaN     51.0        NaN              83.0
# 9     RAHUL SINGH    NaN     56.0       90.0              55.0
# 10    RAHUL KUMAR    NaN      NaN       46.0               NaN
# 11        SAI DAS   52.0      NaN        NaN               NaN
# 12  KARTHIK REDDY   36.0      NaN       83.0               NaN
# 13  ADITYA SHARMA   72.0     87.0        NaN               NaN
# ...

# %%
df['Maths'] = df['Maths']* 1.10

# %%
df
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     ARJUN SINGH   53.9     55.0       48.0              80.0
# 1       ARJUN DAS  103.4     98.0       45.0              68.0
# 2    VIVAAN SINGH  104.5     40.0        NaN              49.0
# 3    VIVAAN PATEL   93.5      NaN       47.0               NaN
# 4       SAI GUPTA    NaN      NaN        NaN              92.0
# 5     AARAV MEHTA   95.7      NaN       78.0              66.0
# 6    SURESH GUPTA   77.0     92.0        NaN               NaN
# 7    ADITYA PATEL   56.1     40.0        NaN              47.0
# 8     RAHUL REDDY    NaN     51.0        NaN              83.0
# 9     RAHUL SINGH    NaN     56.0       90.0              55.0
# 10    RAHUL KUMAR    NaN      NaN       46.0               NaN
# 11        SAI DAS   57.2      NaN        NaN               NaN
# 12  KARTHIK REDDY   39.6      NaN       83.0               NaN
# 13  ADITYA SHARMA   79.2     87.0        NaN               NaN
# ...

# %%
df['Maths'] = df['Maths'].round(-1)

# %%
df
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     ARJUN SINGH   50.0     55.0       48.0              80.0
# 1       ARJUN DAS  100.0     98.0       45.0              68.0
# 2    VIVAAN SINGH  100.0     40.0        NaN              49.0
# 3    VIVAAN PATEL   90.0      NaN       47.0               NaN
# 4       SAI GUPTA    NaN      NaN        NaN              92.0
# 5     AARAV MEHTA  100.0      NaN       78.0              66.0
# 6    SURESH GUPTA   80.0     92.0        NaN               NaN
# 7    ADITYA PATEL   60.0     40.0        NaN              47.0
# 8     RAHUL REDDY    NaN     51.0        NaN              83.0
# 9     RAHUL SINGH    NaN     56.0       90.0              55.0
# 10    RAHUL KUMAR    NaN      NaN       46.0               NaN
# 11        SAI DAS   60.0      NaN        NaN               NaN
# 12  KARTHIK REDDY   40.0      NaN       83.0               NaN
# 13  ADITYA SHARMA   80.0     87.0        NaN               NaN
# ...
