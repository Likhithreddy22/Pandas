# %%
import pandas as pd

# %%
s1 = pd.Series([3,4,7,11,14,17])

# %%
s1
# Out:
# 0     3
# 1     4
# 2     7
# 3    11
# 4    14
# 5    17
# dtype: int64

# %%
s2 = pd.Series([10,20,30,40,50,60],index = ['a','b','c','d','e','f'])

# %%
s2
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
s2['c']
# Out:
# np.int64(30)

# %%
s3 = pd.Series(['1','2','3'])

# %%
s3
# Out:
# 0    1
# 1    2
# 2    3
# dtype: str

# %%
s4 = pd.Series({'alice':25,'bob':30,'charlie':35,'diana':28})

# %%
s4
# Out:
# alice      25
# bob        30
# charlie    35
# diana      28
# dtype: int64

# %%
s4['bob']
# Out:
# np.int64(30)

# %%
s5 = pd.Series(['apple','banana',123,135.65])

# %%
s5
# Out:
# 0     apple
# 1    banana
# 2       123
# 3    135.65
# dtype: object

# %%
s4.dtype
# Out:
# dtype('int64')

# %%
print(s2*2)
# Out:
# a     20
# b     40
# c     60
# d     80
# e    100
# f    120
# dtype: int64

# %%
print(s2+10)
# Out:
# a    20
# b    30
# c    40
# d    50
# e    60
# f    70
# dtype: int64

# %%
print(s2[s2>30])
# Out:
# d    40
# e    50
# f    60
# dtype: int64

# %%
print(s2.index)
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='str')

# %%
print(s2.values)
# Out:
# [10 20 30 40 50 60]

# %%
s2.size
# Out:
# 6
