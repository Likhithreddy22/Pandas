# %%
import pandas as pd

# %%
df = pd.read_csv('student_marks.csv')

# %%
df_sort1 = df.sort_values('Maths',ascending = False)

# %%
df_sort1
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 19    Vivaan Iyer   95.0      NaN        NaN               NaN
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 28     Arjun Iyer   93.0     91.0        NaN               NaN
# 25   Suresh Kumar   90.0     64.0        NaN               NaN
# 46   Nikhil Verma   90.0      NaN        NaN              93.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 41   Aditya Verma   75.0      NaN        NaN               NaN
# 18    Rahul Mehta   75.0     72.0        NaN              38.0
# 16    Rahul Singh   73.0     37.0        NaN              92.0
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 26   Aditya Mehta   59.0     85.0       39.0              76.0
# ...

# %%
df_sort2 = df.sort_values(['Computer_Science','Physics'])

# %%
df_sort2
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 18    Rahul Mehta   75.0     72.0        NaN              38.0
# 37    Rohan Verma   36.0      NaN        NaN              38.0
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 47      Arjun Das    NaN      NaN        NaN              49.0
# 20      Sai Gupta   37.0      NaN       47.0              53.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 24    Aarav Gupta    NaN     99.0        NaN              55.0
# 42      Rohan Das    NaN     92.0       82.0              56.0
# 35   Aditya Singh    NaN      NaN       60.0              57.0
# 17  Karthik Kumar    NaN     68.0       63.0              58.0
# 44  Karthik Kumar   52.0      NaN       69.0              62.0
# 15    Aarav Reddy    NaN      NaN       89.0              63.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# ...

# %%
df = df[['Student_Name','Physics','Computer_Science','Maths','Chemistry']]

# %%
df
# Out:
#      Student_Name  Physics  Computer_Science  Maths  Chemistry
# 0     Arjun Singh     55.0              80.0   49.0       48.0
# 1       Arjun Das     98.0              68.0   94.0       45.0
# 2    Vivaan Singh     40.0              49.0   95.0        NaN
# 3    Vivaan Patel      NaN               NaN   85.0       47.0
# 4       Sai Gupta      NaN              92.0    NaN        NaN
# 5     Aarav Mehta      NaN              66.0   87.0       78.0
# 6    Suresh Gupta     92.0               NaN   70.0        NaN
# 7    Aditya Patel     40.0              47.0   51.0        NaN
# 8     Rahul Reddy     51.0              83.0    NaN        NaN
# 9     Rahul Singh     56.0              55.0    NaN       90.0
# 10    Rahul Kumar      NaN               NaN    NaN       46.0
# 11        Sai Das      NaN               NaN   52.0        NaN
# 12  Karthik Reddy      NaN               NaN   36.0       83.0
# 13  Aditya Sharma     87.0               NaN   72.0        NaN
# ...

# %%
col = df.pop('Maths')

# %%
df.insert(1,'Maths',col)

# %%
df
# Out:
#      Student_Name  Maths  Physics  Computer_Science  Chemistry
# 0     Arjun Singh   49.0     55.0              80.0       48.0
# 1       Arjun Das   94.0     98.0              68.0       45.0
# 2    Vivaan Singh   95.0     40.0              49.0        NaN
# 3    Vivaan Patel   85.0      NaN               NaN       47.0
# 4       Sai Gupta    NaN      NaN              92.0        NaN
# 5     Aarav Mehta   87.0      NaN              66.0       78.0
# 6    Suresh Gupta   70.0     92.0               NaN        NaN
# 7    Aditya Patel   51.0     40.0              47.0        NaN
# 8     Rahul Reddy    NaN     51.0              83.0        NaN
# 9     Rahul Singh    NaN     56.0              55.0       90.0
# 10    Rahul Kumar    NaN      NaN               NaN       46.0
# 11        Sai Das   52.0      NaN               NaN        NaN
# 12  Karthik Reddy   36.0      NaN               NaN       83.0
# 13  Aditya Sharma   72.0     87.0               NaN        NaN
# ...
