# %%
import pandas as pd

# %%
s = pd.Series(['1','2','3'])
s.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
s_int = s.astype('int')

# %%
s_int.dtype
# Out:
# dtype('int64')

# %%
s_float = s.astype('float')

# %%
s_float.dtype
# Out:
# dtype('float64')

# %%
nums = pd.Series([1,2,3])

# %%
nums_str = nums.astype('str')

# %%
nums_str.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
categories = pd.Series(['A','B','C']).astype('category')

# %%
categories_str = categories.astype('str')

# %%
categories.dtype
# Out:
# CategoricalDtype(categories=['A', 'B', 'C'], ordered=False, categories_dtype=str)

# %%
categories_str.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
bool_series = pd.Series([1,0,1,0])

# %%
bool_converted = bool_series.astype('bool')

# %%
bool_converted.dtype
# Out:
# dtype('bool')

# %%
bool_converted
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
date_strings = pd.Series(['2023-01-01','2023-01-02','2023-01-03'])

# %%
dates = date_strings.astype('datetime64[ns]')

# %%
dates.dtype
# Out:
# dtype('<M8[ns]')

# %%
colors = pd.Series(['red','blue','red','green'])

# %%
colors_cat = colors.astype('category')

# %%
colors_cat.dtype
# Out:
# CategoricalDtype(categories=['blue', 'green', 'red'], ordered=False, categories_dtype=str)

# %%
df = pd.DataFrame({
    'A':['1','2','3'],
    'B':[1.1,2.2,3.3],
    'C':[True,False,True]
})

# %%
df['A'] = df['A'].astype('int')

# %%
df['A']
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
df = df.astype({'A':'int','C':'int'})

# %%
df['C']
# Out:
# 0    1
# 1    0
# 2    1
# Name: C, dtype: int64

# %%
df_str = df.astype('str')

# %%
df_str['B']
# Out:
# 0    1.1
# 1    2.2
# 2    3.3
# Name: B, dtype: str

# %%
s = pd.Series(['1','2','not_a_number'])

# %%
s_ignored = s.astype('int',errors = 'ignore') #returns orginal array unchanged when conversion fails

# %%
s_ignored.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
s_coerced = pd.to_numeric(s,errors = 'coerce')

# %%
s_coerced
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64
