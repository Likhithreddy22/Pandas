# %%
import pandas as pd

# %%
dates = pd.Series(pd.date_range('2026-02-20',periods =3,freq='D'))

# %%
dates.dt.year
# Out:
# 0    2026
# 1    2026
# 2    2026
# dtype: int32

# %%
dates.dt.month
# Out:
# 0    2
# 1    2
# 2    2
# dtype: int32

# %%
dates.dt.day
# Out:
# 0    20
# 1    21
# 2    22
# dtype: int32

# %%
dates.dt.dayofyear
# Out:
# 0    51
# 1    52
# 2    53
# dtype: int32

# %%
times = pd.Series(pd.date_range('2023-01-01 ',periods = 5,freq = 'h'))

# %%
times.dt.hour
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int32

# %%
times.dt.minute
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int32

# %%
times.dt.second
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int32

# %%
times.dt.microsecond
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int32

# %%
date = pd.Series(pd.date_range('2025-03-26',periods = 7,freq = 'D'))

# %%
date.dt.day_name()
# Out:
# 0    Wednesday
# 1     Thursday
# 2       Friday
# 3     Saturday
# 4       Sunday
# 5       Monday
# 6      Tuesday
# dtype: str

# %%
date.dt.dayofweek
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    0
# 6    1
# dtype: int32

# %%
date.dt.is_month_start
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
date.dt.is_month_end
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
dates1 = pd.Series(pd.date_range('2026-06-16',periods =3))

# %%
dates1.dt.strftime('%Y-%m-%d')
# Out:
# 0    2026-06-16
# 1    2026-06-17
# 2    2026-06-18
# dtype: str

# %%
dates1.dt.strftime('%A,%B,%d,%Y')
# Out:
# 0      Tuesday,June,16,2026
# 1    Wednesday,June,17,2026
# 2     Thursday,June,18,2026
# dtype: str

# %%
dates.dt.strftime('%I:%M %p')
# Out:
# 0    12:00 AM
# 1    12:00 AM
# 2    12:00 AM
# dtype: str

# %%
dates2 = pd.Series(pd.date_range('2024-09-22 21:30:45',periods =3,freq="h"))

# %%
dates2.dt.round('h')
# Out:
# 0   2024-09-22 22:00:00
# 1   2024-09-22 23:00:00
# 2   2024-09-23 00:00:00
# dtype: datetime64[us]

# %%
dates2.dt.floor('h')
# Out:
# 0   2024-09-22 21:00:00
# 1   2024-09-22 22:00:00
# 2   2024-09-22 23:00:00
# dtype: datetime64[us]

# %%
dates2.dt.ceil('h')
# Out:
# 0   2024-09-22 22:00:00
# 1   2024-09-22 23:00:00
# 2   2024-09-23 00:00:00
# dtype: datetime64[us]
