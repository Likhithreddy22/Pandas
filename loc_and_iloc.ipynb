# %%
import pandas as pd

# %%
df = pd.read_csv('student_marks.csv')

# %%
df
# Out:
#      Student_Name  Maths  Physics  Chemistry  Computer_Science
# 0     Arjun Singh   49.0     55.0       48.0              80.0
# 1       Arjun Das   94.0     98.0       45.0              68.0
# 2    Vivaan Singh   95.0     40.0        NaN              49.0
# 3    Vivaan Patel   85.0      NaN       47.0               NaN
# 4       Sai Gupta    NaN      NaN        NaN              92.0
# 5     Aarav Mehta   87.0      NaN       78.0              66.0
# 6    Suresh Gupta   70.0     92.0        NaN               NaN
# 7    Aditya Patel   51.0     40.0        NaN              47.0
# 8     Rahul Reddy    NaN     51.0        NaN              83.0
# 9     Rahul Singh    NaN     56.0       90.0              55.0
# 10    Rahul Kumar    NaN      NaN       46.0               NaN
# 11        Sai Das   52.0      NaN        NaN               NaN
# 12  Karthik Reddy   36.0      NaN       83.0               NaN
# 13  Aditya Sharma   72.0     87.0        NaN               NaN
# ...

# %%
df.loc[3:36,'Computer_Science']
# Out:
# 3      NaN
# 4     92.0
# 5     66.0
# 6      NaN
# 7     47.0
# 8     83.0
# 9     55.0
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14    76.0
# 15    63.0
# 16    92.0
# 17    58.0
# 18    38.0
# 19     NaN
# 20    53.0
# 21     NaN
# 22    98.0
# 23    67.0
# 24    55.0
# 25     NaN
# 26    76.0
# 27     NaN
# 28     NaN
# 29    88.0
# 30    98.0
# 31     NaN
# 32    98.0
# 33    88.0
# 34     NaN
# 35    57.0
# 36    88.0
# Name: Computer_Science, dtype: float64

# %%
df.loc[7,'Physics']
# Out:
# np.float64(40.0)

# %%
df.loc[7,['Physics','Maths','Chemistry']]
# Out:
# Physics      40.0
# Maths        51.0
# Chemistry     NaN
# Name: 7, dtype: float64

# %%
df.loc[5:10,['Student_Name','Computer_Science']]
# Out:
#     Student_Name  Computer_Science
# 5    Aarav Mehta              66.0
# 6   Suresh Gupta               NaN
# 7   Aditya Patel              47.0
# 8    Rahul Reddy              83.0
# 9    Rahul Singh              55.0
# 10   Rahul Kumar               NaN

# %%
df.loc[19]
# Out:
# Student_Name        Vivaan Iyer
# Maths                      95.0
# Physics                     NaN
# Chemistry                   NaN
# Computer_Science            NaN
# Name: 19, dtype: object

# %%
df.loc[[10,20,40]]
# Out:
#     Student_Name  Maths  Physics  Chemistry  Computer_Science
# 10   Rahul Kumar    NaN      NaN       46.0               NaN
# 20     Sai Gupta   37.0      NaN       47.0              53.0
# 40  Suresh Gupta   49.0     98.0       48.0               NaN

# %%
df.iloc[0,0]
# Out:
# 'Arjun Singh'

# %%
df.iloc[1,4]
# Out:
# np.float64(68.0)

# %%
df.iloc[[1,7]]
# Out:
#    Student_Name  Maths  Physics  Chemistry  Computer_Science
# 1     Arjun Das   94.0     98.0       45.0              68.0
# 7  Aditya Patel   51.0     40.0        NaN              47.0

# %%
df.iloc[1:8]
# Out:
#    Student_Name  Maths  Physics  Chemistry  Computer_Science
# 1     Arjun Das   94.0     98.0       45.0              68.0
# 2  Vivaan Singh   95.0     40.0        NaN              49.0
# 3  Vivaan Patel   85.0      NaN       47.0               NaN
# 4     Sai Gupta    NaN      NaN        NaN              92.0
# 5   Aarav Mehta   87.0      NaN       78.0              66.0
# 6  Suresh Gupta   70.0     92.0        NaN               NaN
# 7  Aditya Patel   51.0     40.0        NaN              47.0

# %%
df.iloc[0:10,0:3]
# Out:
#    Student_Name  Maths  Physics
# 0   Arjun Singh   49.0     55.0
# 1     Arjun Das   94.0     98.0
# 2  Vivaan Singh   95.0     40.0
# 3  Vivaan Patel   85.0      NaN
# 4     Sai Gupta    NaN      NaN
# 5   Aarav Mehta   87.0      NaN
# 6  Suresh Gupta   70.0     92.0
# 7  Aditya Patel   51.0     40.0
# 8   Rahul Reddy    NaN     51.0
# 9   Rahul Singh    NaN     56.0
