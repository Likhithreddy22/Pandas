# %%
import pandas as pd

# %%
s = pd.Series(['Hello','PyThOn','Pandas'])

# %%
s.str.lower()
# Out:
# 0     hello
# 1    python
# 2    pandas
# dtype: str

# %%
s.str.upper()
# Out:
# 0     HELLO
# 1    PYTHON
# 2    PANDAS
# dtype: str

# %%
s.str.title()
# Out:
# 0     Hello
# 1    Python
# 2    Pandas
# dtype: str

# %%
s.str.capitalize()
# Out:
# 0     Hello
# 1    Python
# 2    Pandas
# dtype: str

# %%
s.str.len()
# Out:
# 0    5
# 1    6
# 2    6
# dtype: int64

# %%
s2 = pd.Series([' apple ',' banana ',' cherry '])

# %%
s2.str.strip() #strip whitespaces
# Out:
# 0     apple
# 1    banana
# 2    cherry
# dtype: str

# %%
s2.str.lstrip()
# Out:
# 0     apple
# 1    banana
# 2    cherry
# dtype: str

# %%
s2.str.rstrip()
# Out:
# 0      apple
# 1     banana
# 2     cherry
# dtype: str

# %%
s3 = pd.Series(['apple_pie','banana_split','cherry_pie'])

# %%
s3.str.replace('_',' ')
# Out:
# 0       apple pie
# 1    banana split
# 2      cherry pie
# dtype: str

# %%
s3.str.find('pie')
# Out:
# 0    6
# 1   -1
# 2    7
# dtype: int64

# %%
s3.str.contains('pie')
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
s4 =pd.Series(['John,Doe','Jane,Smith','Bob,Johnson'])

# %%
s4.str.split(',')
# Out:
# 0       [John, Doe]
# 1     [Jane, Smith]
# 2    [Bob, Johnson]
# dtype: object

# %%
s4.str.split(',').str[0]
# Out:
# 0    John
# 1    Jane
# 2     Bob
# dtype: object

# %%
s4.str.split(',').str[1]
# Out:
# 0        Doe
# 1      Smith
# 2    Johnson
# dtype: object

# %%
s41 = pd.Series([['John','Doe'],['Jane','Smith'],['Bob','Johnson']])
s41.str.join(' ')
# Out:
# 0       John Doe
# 1     Jane Smith
# 2    Bob Johnson
# dtype: object

# %%
s5 = pd.Series(['apple',34,'banana',76.6])

# %%
s5.str.isalpha()
# Out:
# 0    True
# 1     NaN
# 2    True
# 3     NaN
# dtype: object

# %%
s5.str.isnumeric()
# Out:
# 0    False
# 1      NaN
# 2    False
# 3      NaN
# dtype: object

# %%
s5.str.startswith('a')
# Out:
# 0     True
# 1      NaN
# 2    False
# 3      NaN
# dtype: object

# %%
s5.str.islower()
# Out:
# 0    True
# 1     NaN
# 2    True
# 3     NaN
# dtype: object

# %%
s6 = pd.Series(['abcdef','ghijkl','mnopqr'])

# %%
s6.str[:3]
# Out:
# 0    abc
# 1    ghi
# 2    mno
# dtype: str

# %%
s6.str[-2:]
# Out:
# 0    ef
# 1    kl
# 2    qr
# dtype: str

# %%
s6.str[2]
# Out:
# 0    c
# 1    i
# 2    o
# dtype: str
